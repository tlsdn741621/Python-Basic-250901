# %%
# 실전 예제로 주식 데이터(삼성전자, 카카오, 네이버) 를 활용하여
# 주가 변동을 시각화하는 예제를 만들어보겠습니다.
#
# 이 예제에서는 Matplotlib과 Pandas를 활용하여 다음을 분석합니다:
#
# 주가 변동 라인 그래프
# 삼성전자, 카카오, 네이버의 주가 변동을 하나의 그래프로 시각화합니다.
#
# 이동 평균선 추가
# 단기(5일) 및 장기(20일) 이동 평균선을 추가하여 주가 추세를 분석합니다.
#
# 히트맵을 통한 상관관계 분석
# 삼성전자, 카카오, 네이버의 주가 상관관계를 히트맵으로 표현합니다.
#
#
# 1. 주식 데이터 수집 및 처리
# 먼저, 삼성전자(005930), 카카오(035720), 네이버(035420)의 주가 데이터를 가져오겠습니다.
# 실시간 주식 데이터를 사용하기 위해, web을 이용하여 최신 데이터를 검색합니다.
#
# 실전 예제로 삼성전자, 네이버, 카카오의 주가 데이터를 활용하여 주가 변동을 시각화하는 방법을 안내하겠습니다. 이를 통해 주가 변동 추이와 종목 간 상관관계를 분석할 수 있습니다.
#
#
#
# 1. 주가 데이터 수집
# 주가 데이터를 수집하기 위해 yahoo_fin 라이브러리를 사용합니다. 이 라이브러리는 야후 파이낸스에서 주가 데이터를 가져올 수 있도록 도와줍니다.
#
# 필요한 라이브러리 설치:
# !pip install yahoo_fin pandas matplotlib seaborn

# %%
# !pip install yahoo_fin pandas matplotlib seaborn
# !pip install requests_html
# Out:
# Collecting yahoo_fin
#   Using cached yahoo_fin-0.8.9.1-py3-none-any.whl.metadata (699 bytes)
# Requirement already satisfied: pandas in c:\program files\python\python313\lib\site-packages (2.3.2)
# Requirement already satisfied: matplotlib in c:\program files\python\python313\lib\site-packages (3.10.6)
# Requirement already satisfied: seaborn in c:\program files\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: requests-html in c:\program files\python\python313\lib\site-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: feedparser in c:\program files\python\python313\lib\site-packages (from yahoo_fin) (6.0.11)
# Requirement already satisfied: requests in c:\program files\python\python313\lib\site-packages (from yahoo_fin) (2.32.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\program files\python\python313\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\it\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\program files\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\program files\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\program files\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\program files\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\program files\python\python313\lib\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\program files\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\it\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\program files\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\program files\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\it\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: sgmllib3k in c:\program files\python\python313\lib\site-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\program files\python\python313\lib\site-packages (from requests->yahoo_fin) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\python\python313\lib\site-packages (from requests->yahoo_fin) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\program files\python\python313\lib\site-packages (from requests->yahoo_fin) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\python\python313\lib\site-packages (from requests->yahoo_fin) (2025.8.3)
# Requirement already satisfied: pyquery in c:\program files\python\python313\lib\site-packages (from requests-html->yahoo_fin) (2.0.1)
# Requirement already satisfied: fake-useragent in c:\program files\python\python313\lib\site-packages (from requests-html->yahoo_fin) (2.2.0)
# Requirement already satisfied: parse in c:\program files\python\python313\lib\site-packages (from requests-html->yahoo_fin) (1.20.2)
# Requirement already satisfied: bs4 in c:\program files\python\python313\lib\site-packages (from requests-html->yahoo_fin) (0.0.2)
# Requirement already satisfied: w3lib in c:\program files\python\python313\lib\site-packages (from requests-html->yahoo_fin) (2.3.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\program files\python\python313\lib\site-packages (from requests-html->yahoo_fin) (2.0.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\program files\python\python313\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\program files\python\python313\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.7.0)
# Requirement already satisfied: pyee<12.0.0,>=11.0.0 in c:\program files\python\python313\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (11.1.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\program files\python\python313\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.67.1)
# Collecting websockets<11.0,>=10.0 (from pyppeteer>=0.0.14->requests-html->yahoo_fin)
#   Using cached websockets-10.4-cp313-cp313-win_amd64.whl
# Requirement already satisfied: typing-extensions in c:\program files\python\python313\lib\site-packages (from pyee<12.0.0,>=11.0.0->pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.15.0)
# Requirement already satisfied: colorama in c:\users\it\appdata\roaming\python\python313\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests-html->yahoo_fin) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in c:\program files\python\python313\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.23.0)
# Requirement already satisfied: beautifulsoup4 in c:\program files\python\python313\lib\site-packages (from bs4->requests-html->yahoo_fin) (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in c:\program files\python\python313\lib\site-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.8)
# Requirement already satisfied: lxml>=2.1 in c:\program files\python\python313\lib\site-packages (from pyquery->requests-html->yahoo_fin) (6.0.1)
# Requirement already satisfied: cssselect>=1.2.0 in c:\program files\python\python313\lib\site-packages (from pyquery->requests-html->yahoo_fin) (1.3.0)
# Using cached yahoo_fin-0.8.9.1-py3-none-any.whl (10 kB)
# Installing collected packages: websockets, yahoo_fin
#
#   Attempting uninstall: websockets
#
#     Found existing installation: websockets 15.0.1
#
#     Uninstalling websockets-15.0.1:
#
#       Successfully uninstalled websockets-15.0.1
#
#    ---------------------------------------- 0/2 [websockets]
#    -------------------- ------------------- 1/2 [yahoo_fin]
#    ---------------------------------------- 2/2 [yahoo_fin]
#
# Successfully installed websockets-10.4 yahoo_fin-0.8.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yfinance 0.2.65 requires websockets>=13.0, but you have websockets 10.4 which is incompatible.
# Requirement already satisfied: requests_html in c:\program files\python\python313\lib\site-packages (0.10.0)
# Requirement already satisfied: requests in c:\program files\python\python313\lib\site-packages (from requests_html) (2.32.5)
# Requirement already satisfied: pyquery in c:\program files\python\python313\lib\site-packages (from requests_html) (2.0.1)
# Requirement already satisfied: fake-useragent in c:\program files\python\python313\lib\site-packages (from requests_html) (2.2.0)
# Requirement already satisfied: parse in c:\program files\python\python313\lib\site-packages (from requests_html) (1.20.2)
# Requirement already satisfied: bs4 in c:\program files\python\python313\lib\site-packages (from requests_html) (0.0.2)
# Requirement already satisfied: w3lib in c:\program files\python\python313\lib\site-packages (from requests_html) (2.3.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\program files\python\python313\lib\site-packages (from requests_html) (2.0.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\program files\python\python313\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: certifi>=2023 in c:\program files\python\python313\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (2025.8.3)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\program files\python\python313\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (8.7.0)
# Requirement already satisfied: pyee<12.0.0,>=11.0.0 in c:\program files\python\python313\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (11.1.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\program files\python\python313\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (4.67.1)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\program files\python\python313\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.26.20)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\program files\python\python313\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (10.4)
# Requirement already satisfied: typing-extensions in c:\program files\python\python313\lib\site-packages (from pyee<12.0.0,>=11.0.0->pyppeteer>=0.0.14->requests_html) (4.15.0)
# Requirement already satisfied: colorama in c:\users\it\appdata\roaming\python\python313\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests_html) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in c:\program files\python\python313\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.23.0)
# Requirement already satisfied: beautifulsoup4 in c:\program files\python\python313\lib\site-packages (from bs4->requests_html) (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in c:\program files\python\python313\lib\site-packages (from beautifulsoup4->bs4->requests_html) (2.8)
# Requirement already satisfied: lxml>=2.1 in c:\program files\python\python313\lib\site-packages (from pyquery->requests_html) (6.0.1)
# Requirement already satisfied: cssselect>=1.2.0 in c:\program files\python\python313\lib\site-packages (from pyquery->requests_html) (1.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\program files\python\python313\lib\site-packages (from requests->requests_html) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\python\python313\lib\site-packages (from requests->requests_html) (3.10)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from yahoo_fin import stock_info as si

# 종목 코드 설정
tickers = {
    '삼성전자': '005930.KS',
    '네이버': '035420.KS',
    '카카오': '035720.KS'
}

# 데이터 수집
data = {}
for company, ticker in tickers.items():
    data[company] = si.get_data(ticker, start_date='2022-01-01', end_date='2025-01-01')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File C:\Program Files\Python\Python313\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File C:\Program Files\Python\Python313\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File C:\Program Files\Python\Python313\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File C:\Program Files\Python\Python313\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[22], line 16
#      14 data = {}
#      15 for company, ticker in tickers.items():
# ---> 16     data[company] = si.get_data(ticker, start_date='2022-01-01', end_date='2025-01-01')
#
# File C:\Program Files\Python\Python313\Lib\site-packages\yahoo_fin\stock_info.py:90, in get_data(ticker, start_date, end_date, index_as_date, interval, headers)
#      86 resp = requests.get(site, params = params, headers = headers)
#      89 if not resp.ok:
# ---> 90     raise AssertionError(resp.json())
#      93 # get JSON response
#      94 data = resp.json()
#
# File C:\Program Files\Python\Python313\Lib\site-packages\requests\models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.65-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\program files\python\python313\lib\site-packages (from yfinance) (2.3.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\program files\python\python313\lib\site-packages (from yfinance) (2.3.2)
# Requirement already satisfied: requests>=2.31 in c:\program files\python\python313\lib\site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\it\appdata\roaming\python\python313\site-packages (from yfinance) (4.4.0)
# Requirement already satisfied: pytz>=2022.5 in c:\program files\python\python313\lib\site-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.6-py313-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.2.tar.gz (949 kB)
#      ---------------------------------------- 0.0/949.2 kB ? eta -:--:--
#      ---------------------------------------- 949.2/949.2 kB 27.3 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\program files\python\python313\lib\site-packages (from yfinance) (4.13.5)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl.metadata (13 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Downloading protobuf-6.32.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\program files\python\python313\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\program files\python\python313\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\program files\python\python313\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\program files\python\python313\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.8.3)
# Requirement already satisfied: pycparser in c:\program files\python\python313\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\it\appdata\roaming\python\python313\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\program files\python\python313\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\it\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\program files\python\python313\lib\site-packages (from requests>=2.31->yfinance) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\python\python313\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\program files\python\python313\lib\site-packages (from requests>=2.31->yfinance) (1.26.20)
# Downloading yfinance-0.2.65-py2.py3-none-any.whl (119 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 65.5 MB/s  0:00:00
# Downloading frozendict-2.4.6-py313-none-any.whl (16 kB)
# Downloading protobuf-6.32.0-cp310-abi3-win_amd64.whl (435 kB)
# Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl (176 kB)
# Building wheels for collected packages: multitasking, peewee
#   Building wheel for multitasking (pyproject.toml): started
#   Building wheel for multitasking (pyproject.toml): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15703 sha256=15be9d0001754bd7c73176d9cc6e0c6c2343b433189acbd90770954fe727e7a1
#   Stored in directory: c:\users\it\appdata\local\pip\cache\wheels\1e\df\0f\e2bbb22d689b30c681feb5410ab64a2523437b34c8ecfc6476
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.18.2-py3-none-any.whl size=139153 sha256=7ea157c137b6d6016f697dc1dffecb8b9d481a8a678b3d956bc9aa80c182b139
#   Stored in directory: c:\users\it\appdata\local\pip\cache\wheels\1c\48\cc\00b7d0e7defa21a58915654917c89eaedd32a6e614d8e4ad92
# Successfully built multitasking peewee
# Installing collected packages: peewee, multitasking, websockets, protobuf, frozendict, curl_cffi, yfinance
#
#    ---------------------------------------- 0/7 [peewee]
#    ---------------------------------------- 0/7 [peewee]
#   Attempting uninstall: websockets
#    ---------------------------------------- 0/7 [peewee]
#     Found existing installation: websockets 10.4
#    ---------------------------------------- 0/7 [peewee]
#     Uninstalling websockets-10.4:
#    ---------------------------------------- 0/7 [peewee]
#       Successfully uninstalled websockets-10.4
#    ---------------------------------------- 0/7 [peewee]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ---------------------------- ----------- 5/7 [curl_cffi]
#    ---------------------------- ----------- 5/7 [curl_cffi]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------------- 7/7 [yfinance]
#
# Successfully installed curl_cffi-0.13.0 frozendict-2.4.6 multitasking-0.0.12 peewee-3.18.2 protobuf-6.32.0 websockets-15.0.1 yfinance-0.2.65
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyppeteer 2.0.0 requires websockets<11.0,>=10.0, but you have websockets 15.0.1 which is incompatible.

# %%
import time
import pandas as pd
import requests
from yahoo_fin import stock_info as si
import yfinance as yf

# ---------------------------
# 1. 종목 코드 설정
# ---------------------------
tickers = {
    '삼성전자': '005930.KS',
    '네이버'  : '035420.KS',
    '카카오'  : '035720.KS'
}

# 헤더 (야후 차단 방지용)
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/124.0.0.0 Safari/537.36"
    )
}

# ---------------------------
# 2. 데이터 수집 함수
# ---------------------------
def get_data_yahoo_fin(ticker, start, end, headers=None):
    return si.get_data(
        ticker,
        start_date=start,
        end_date=end,
        index_as_date=True,
        interval="1d",
        headers=headers
    )

def get_data_yfinance(ticker, start, end):
    df = yf.download(
        ticker,
        start=start,
        end=end,
        progress=False,
        auto_adjust=True,
        threads=False
    )
    if df is not None and not df.empty:
        df = df.rename(columns={
            "Open": "open",
            "High": "high",
            "Low": "low",
            "Close": "close",
            "Adj Close": "adjclose",
            "Volume": "volume"
        })
    return df

def get_data_safe(ticker, start="2022-01-01", end="2025-01-01",
                  retries=3, backoff=2.0, headers=HEADERS):
    last_exc = None
    for i in range(retries):
        try:
            df = get_data_yahoo_fin(ticker, start, end, headers=headers)
            if df is not None and not df.empty:
                return df
        except Exception as e:
            last_exc = e
        time.sleep(backoff * (i + 1))
    # 폴백
    df_fb = get_data_yfinance(ticker, start, end)
    if df_fb is not None and not df_fb.empty:
        return df_fb
    raise RuntimeError(f"Failed to fetch {ticker}") from last_exc

# ---------------------------
# 3. 데이터 수집 및 CSV 저장
# ---------------------------
all_data = {}

for company, ticker in tickers.items():
    try:
        df = get_data_safe(ticker, start="2022-01-01", end="2025-09-01")
        df["company"] = company  # 회사명 컬럼 추가
        all_data[company] = df
        print(f"[OK] {company} ({ticker}) rows={len(df)}")
        time.sleep(0.7)
    except Exception as e:
        print(f"[FAIL] {company} ({ticker}) -> {e}")

# 하나의 DataFrame으로 합치기
combined = pd.concat(all_data.values())
combined.index.name = "date"

# CSV 저장
csv_path = "stock_data.csv"
combined.to_csv(csv_path, encoding="utf-8-sig")
print(f"CSV 저장 완료: {csv_path}")

# ---------------------------
# 4. 저장된 CSV 불러오기
# ---------------------------
loaded = pd.read_csv(csv_path, parse_dates=["date"])
print("불러온 데이터 크기:", loaded.shape)
print(loaded.head())
# Out:
# [OK] 삼성전자 (005930.KS) rows=895
# [OK] 네이버 (035420.KS) rows=895
# [OK] 카카오 (035720.KS) rows=895
# CSV 저장 완료: stock_data.csv
# 불러온 데이터 크기: (2685, 9)
#         date     open     high      low    close      adjclose    volume  \
# 0 2022-01-04  78800.0  79200.0  78300.0  78700.0  72762.890625  12427416
# 1 2022-01-05  78800.0  79000.0  76400.0  77400.0  71560.945312  25470640
# 2 2022-01-06  76700.0  77600.0  76600.0  76900.0  71098.664062  12931954
# 3 2022-01-07  78100.0  78400.0  77400.0  78300.0  72393.046875  15163757
# 4 2022-01-10  78100.0  78100.0  77100.0  78000.0  72115.671875   9947422
#
#       ticker company
# 0  005930.KS    삼성전자
# 1  005930.KS    삼성전자
# 2  005930.KS    삼성전자
# 3  005930.KS    삼성전자
# 4  005930.KS    삼성전자

# %%
# CSV에서 불러온 데이터 활용
# (loaded는 [date, open, high, low, close, adjclose, volume, company] 구조)

# pivot_table 또는 pivot 사용
close_prices = loaded.pivot(index="date", columns="company", values="close")
# 결과 확인
print(close_prices.head())

# 빈 DataFrame 생성
close_prices_alt = pd.DataFrame()

# company별로 close만 추출해 열 단위로 추가
for company in tickers.keys():
    company_df = loaded[loaded["company"] == company]
    close_prices_alt[company] = company_df.set_index("date")["close"]

# 결과 확인
print(close_prices_alt.head())
# Out:
# company          네이버     삼성전자       카카오
# date
# 2022-01-04  365500.0  78700.0  111500.0
# 2022-01-05  355000.0  77400.0  105500.0
# 2022-01-06  338500.0  76900.0  100000.0
# 2022-01-07  338000.0  78300.0  100000.0
# 2022-01-10  335000.0  78000.0   96600.0
#                삼성전자       네이버       카카오
# date
# 2022-01-04  78700.0  365500.0  111500.0
# 2022-01-05  77400.0  355000.0  105500.0
# 2022-01-06  76900.0  338500.0  100000.0
# 2022-01-07  78300.0  338000.0  100000.0
# 2022-01-10  78000.0  335000.0   96600.0

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

# 한글 폰트 경로 설정 (Windows)
font_path = "C:/Windows/Fonts/malgun.ttf"  # '맑은 고딕' 폰트 경로

font_prop = fm.FontProperties(fname=font_path)

# Matplotlib 기본 폰트 설정
plt.rcParams['font.family'] = font_prop.get_name()

# 음수 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False


plt.figure(figsize=(14, 7))
for company in close_prices.columns:
    plt.plot(close_prices.index, close_prices[company], label=company)

plt.title('삼성전자, 네이버, 카카오 주가 변동 (2022-2025)', fontproperties=font_prop)
plt.xlabel('날짜', fontproperties=font_prop)
plt.ylabel('주가 (원)', fontproperties=font_prop)
plt.legend(prop=font_prop)
plt.grid(True)
plt.show()

# %%
# 4. 이동 평균선 추가
# 주가의 단기 및 장기 추세를 파악하기 위해 20일 및 60일 이동 평균선을 계산하고 시각화합니다.

# %%
# 이동 평균선 계산
ma_days = [20, 60]
for ma in ma_days:
    for company in close_prices.columns:
        column_name = f'{company} {ma}일 이동평균'
        close_prices[column_name] = close_prices[company].rolling(window=ma).mean()

# 시각화
plt.figure(figsize=(14, 7))
for company in close_prices.columns[:3]:
    plt.plot(close_prices.index, close_prices[company], label=company)
    for ma in ma_days:
        plt.plot(close_prices.index, close_prices[f'{company} {ma}일 이동평균'],
                 label=f'{company} {ma}일 이동평균')

plt.title('주가 변동 및 이동평균선', fontproperties=font_prop)
plt.xlabel('날짜', fontproperties=font_prop)
plt.ylabel('주가 (원)', fontproperties=font_prop)
plt.legend(prop=font_prop)
plt.grid(True)
plt.show()

# %%
# 📌 종가 데이터의 상관계수 계산
corr = close_prices.corr()

# 📌 히트맵 시각화 (한글 폰트 적용)
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1,
            annot_kws={"fontsize": 12, "fontproperties": font_prop}, fmt=".2f")

# 📌 그래프 제목 및 축 레이블 한글 적용
plt.title("삼성전자, 네이버, 카카오 주가 상관관계", fontproperties=font_prop)
plt.xlabel("종목명", fontproperties=font_prop)
plt.ylabel("종목명", fontproperties=font_prop)

plt.show()
